# %% [markdown]
# # Speed Dating

# %% [markdown]
# Import des bibliothèques

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eee56b40-49a6-4dd4-a422-dd2cd220e6fa" name="files[]" multiple disabled />
#      <output id="result-eee56b40-49a6-4dd4-a422-dd2cd220e6fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %%
data_set = pd.read_csv('data.csv', encoding = "ISO-8859-1")
dataset= data_set

# %%
dataset.head(20)
# Out:
#     iid   id  gender  idg  condtn  ...  attr5_3  sinc5_3  intel5_3  fun5_3  amb5_3
# 0     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 1     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 2     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 3     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 4     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 5     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 6     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 7     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 8     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# 9     1  1.0       0    1       1  ...      NaN      NaN       NaN     NaN     NaN
# ...

# %% [markdown]
# Etude sur les matchs des personnes de même origine

# %%
same_race = dataset.samerace==1

# %%
match_same_race = dataset.match[same_race]
match_all = dataset.match

# %%
match_all
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 8373    0
# 8374    0
# 8375    0
# 8376    0
# 8377    0
# Name: match, Length: 8378, dtype: int64

# %%
match_same_race.value_counts()
# Out:
# 0    2750
# 1     566
# Name: match, dtype: int64

# %%
# On créé notre graphique 
names = ["No Match", "Match"]

plt.title("Match en fonction origine commune")
p1 = plt.bar(names,match_all.value_counts()-match_same_race.value_counts())
p2 = plt.bar(names,match_all.value_counts()-match_same_race.value_counts(), bottom=match_same_race.value_counts())
plt.show()

# %% [markdown]
# ##Qu'est ce que recherche les hommes VS les femmes

# %%
#add_1 = dataset.iloc[:,0:43]
#add_2 = dataset.iloc[:,45:65]
#add_3 = dataset.iloc[:,67:117]
#add_4 = dataset.iloc[:,119:121]
#add_5 = dataset.iloc[:,128:150]
#dataset2 = pd.concat([add_1,add_2,add_3,add_4,add_5], axis=1)
#d = dataset2.isnull().sum()
#d

# %%
#Creation de masks
look_for = ["attr1_1","sinc1_1","intel1_1","fun1_1","amb1_1","shar1_1","gender","iid"]
opp_look_for = ["attr2_1","sinc2_1","fun2_1","amb2_1"]
own_score = ["attr3_1","sinc3_1","fun3_1","amb3_1"]
think_own_score = ["attr5_1","sinc5_1","fun5_1","amb5_1"]

looking_dataset = dataset[look_for]
looking_dataset
# Out:
#       attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1  gender  iid
# 0        15.0     20.0      20.0    15.0    15.0     15.0       0    1
# 1        15.0     20.0      20.0    15.0    15.0     15.0       0    1
# 2        15.0     20.0      20.0    15.0    15.0     15.0       0    1
# 3        15.0     20.0      20.0    15.0    15.0     15.0       0    1
# 4        15.0     20.0      20.0    15.0    15.0     15.0       0    1
# ...       ...      ...       ...     ...     ...      ...     ...  ...
# 8373     70.0      0.0      15.0    15.0     0.0      0.0       1  552
# 8374     70.0      0.0      15.0    15.0     0.0      0.0       1  552
# 8375     70.0      0.0      15.0    15.0     0.0      0.0       1  552
# 8376     70.0      0.0      15.0    15.0     0.0      0.0       1  552
# 8377     70.0      0.0      15.0    15.0     0.0      0.0       1  552
#
# [8378 rows x 8 columns]

# %%
look_values = looking_dataset.iloc[0:8378,0:6]
look_values
# Out:
#       attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  shar1_1
# 0        15.0     20.0      20.0    15.0    15.0     15.0
# 1        15.0     20.0      20.0    15.0    15.0     15.0
# 2        15.0     20.0      20.0    15.0    15.0     15.0
# 3        15.0     20.0      20.0    15.0    15.0     15.0
# 4        15.0     20.0      20.0    15.0    15.0     15.0
# ...       ...      ...       ...     ...     ...      ...
# 8373     70.0      0.0      15.0    15.0     0.0      0.0
# 8374     70.0      0.0      15.0    15.0     0.0      0.0
# 8375     70.0      0.0      15.0    15.0     0.0      0.0
# 8376     70.0      0.0      15.0    15.0     0.0      0.0
# 8377     70.0      0.0      15.0    15.0     0.0      0.0
#
# [8378 rows x 6 columns]

# %%
homme=looking_dataset.gender==0
femme=looking_dataset.gender==1

labels=["Attractif","Sincère","Intello","Drole","Ambitieux","Meme delires"]
x = np.arange(len(labels))
width = 0.35

femme_means = look_values[femme].mean()
homme_means = look_values[homme].mean()

# %%
fig, ax = plt.subplots()
men = ax.bar(x - width/2, homme_means, width=0.35, label='Men')
women = ax.bar(x + width/2, femme_means, width=0.35, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel("% Interet")
ax.set_title("Ce que recherche les Femmes VS Hommes")
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %%
plt.subplots(figsize=(20,15))
ax = plt.axes()
ax.set_title("Ce que l'on croit qui plaît par rapport à sa description\n", size=20)
corr = dataset[opp_look_for+own_score].corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
d= dataset.isnull().sum()

# %%
pd.options.display.max_rows = 200
d
# Out:
# iid            0
# id             1
# gender         0
# idg            0
# condtn         0
# wave           0
# round          0
# position       0
# positin1    1846
# order          0
# partner        0
# pid           10
# match          0
# int_corr     158
# samerace       0
# age_o        104
# race_o        73
# pf_o_att      89
# pf_o_sin      89
# pf_o_int      89
# pf_o_fun      98
# pf_o_amb     107
# pf_o_sha     129
# dec_o          0
# attr_o       212
# sinc_o       287
# intel_o      306
# fun_o        360
# amb_o        722
# shar_o      1076
# like_o       250
# prob_o       318
# met_o        385
# age           95
# field         63
# field_cd      82
# undergra    3464
# mn_sat      5245
# tuition     4795
# race          63
# imprace       79
# imprelig      79
# from          79
# zipcode     1064
# income      4099
# goal          79
# date          97
# go_out        79
# career        89
# career_c     138
# sports        79
# tvsports      79
# ...

# %%
pd.options.display.max_rows = 200
